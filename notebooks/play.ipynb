# %%
# Install prettymaps using pip:
# !pip install -e ../
# Out:
# Obtaining file:///home/koji/work/prettymaps
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for prettymaps (pyproject.toml) ... done
#   Created wheel for prettymaps: filename=prettymaps-1.0.0-0.editable-py3-none-any.whl size=21087 sha256=b9f1e34d8b6e7745034cc0c9ac9124f43a5ea3ec89a5412b0c3ef4193c406918
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vrea_ijq/wheels/93/2a/ff/5fead5aef884c0fe59017ab659e083aded380b9a274f161d4e
# Successfully built prettymaps
# ...
#   Attempting uninstall: prettymaps
#     Found existing installation: prettymaps 1.0.0
#     Uninstalling prettymaps-1.0.0:
#       Successfully uninstalled prettymaps-1.0.0
# ...

# %%
import prettymaps

plot = prettymaps.plot('Stad van de Zon, Heerhugowaard, Netherlands')

# %%
plot = prettymaps.plot(
    'Praça Ferreira do Amaral, Macau',
    circle = True,
    radius = 300,
    save_as="macau-circle-300.png"
)
# Out:
# /home/koji/work/prettymaps/.venv/lib/python3.10/site-packages/osmnx/geometries.py:358: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf["geometry"] = np.nan
# ...
